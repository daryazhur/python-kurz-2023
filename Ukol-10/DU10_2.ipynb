# %% [markdown]
# Pokračuj ve své práci pro softwarovou firmu. Ze souboru vykazy.csv načti informace o výkazech na projekty pro jednoho vybraného zákazníka.
#
# * Načti data ze souboru a ulož je do tabulky.
# * Proveď agregaci a zjisti celkový počet vykázaných hodin za jednotlivé projekty.

# %%
import pandas

zamestnanci = pandas.read_csv('zamestnanci.csv')

# %% [markdown]
# * Načti data ze souboru a ulož je do tabulky.

# %%
vykazy = pandas.read_csv('vykazy.csv')

vykazy = vykazy.rename(columns = {'date' : 'datum', 'hours':'casy', 'project':'projekt', 'emloyee_id':'cislo_zamestnance'})

vykazy_zamestnanci = pandas.merge(vykazy, zamestnanci, on = ['cislo_zamestnance'])
vykazy_zamestnanci
# Out:
#          datum  casy projekt  cislo_zamestnance      jmeno    prijimeni
# 0   2021-02-01   2.5     F30                 13  Alexander     Martinez  \
# 1   2021-02-01   3.4     W05                 70     Dillon        Black
# 2   2021-02-01   2.1     JL9                 72     Robert         Říha
# 3   2021-02-01   5.2     F30                  3      Stacy  Pospíšilová
# 4   2021-02-01   2.4     TE1                 54   Michelle      Vlčková
# 5   2021-02-01   4.1     TE1                 83       Nela      Šťastná
# 6   2021-02-01   5.4     W05                 92      Vasyl       Veselý
# 7   2021-02-01   2.2     YLI                 34   Dominika      Kopecká
# 8   2021-02-03   2.6     YLI                 34   Dominika      Kopecká
# 9   2021-02-01   2.7     YLI                 84    Heather      Marková
# 10  2021-02-01   4.4     W05                 30      Brian         Hall
# 11  2021-02-02   5.6     F30                 53   Karolína        Short
# ...

# %% [markdown]
# * Proveď agregaci a zjisti celkový počet vykázaných hodin za jednotlivé projekty.

# %%
vykazy_zamestnanci.groupby('projekt')['casy'].count()
# Out:
# projekt
# F30    5
# JL9    1
# TE1    5
# W05    7
# YLI    9
# Name: casy, dtype: int64
